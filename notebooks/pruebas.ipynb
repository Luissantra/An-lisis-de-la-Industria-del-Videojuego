# %%
import os
import pandas as pd

# Ir al directorio padre
os.chdir('..')
df = pd.read_csv('data/processed/studios_geocoded.csv')
unique_countries = df['Country'].unique()
print(unique_countries)
print(f"Total unique countries: {len(unique_countries)}")
# Out:
# ['UNITED STATES' 'SERBIA' 'TURKEY' 'GERMANY' 'SPAIN' 'PERU' 'FRANCE'
#  'GREECE' 'VIETNAM' 'URUGUAY' 'RUSSIA' 'CHILE' 'CANADA' 'BRAZIL' 'ITALY'
#  'NEW ZEALAND' 'AUSTRALIA' 'BELARUS' 'BULGARIA' 'NORTH MACEDONIA'
#  'FINLAND' 'INDIA' 'MEXICO' 'WALES' 'SCOTLAND' 'CHINA' 'UKRAINE'
#  'THAILAND' 'SWEDEN' 'SWITZERLAND' 'POLAND' 'ROMANIA' 'EGYPT' 'HUNGARY'
#  'CZECHIA' 'CROATIA' 'SLOVENIA' 'SLOVAKIA' 'AUSTRIA' 'ARGENTINA' 'JAPAN'
#  'SOUTH AFRICA' 'MOROCCO' 'LITHUANIA' 'ENGLAND' 'BELGIUM' 'NETHERLANDS'
#  'LUXEMBOURG' 'PHILIPPINES' 'MALAYSIA' 'SINGAPORE' 'BRUNEI' 'TAIWAN'
#  'SOUTH KOREA' 'PAKISTAN' 'SYRIA' 'STATES OF JERSEY' 'UNITED KINGDOM'
#  'NORWAY' 'DENMARK' 'RHONE-ALPES' 'PORTUGAL' 'ICELAND' 'ISRAEL' 'ESTONIA'
#  'LATVIA' 'COSTA RICA' 'COLOMBIA' 'INDONESIA' 'GUATEMALA' 'MALTA' 'JORDAN'
#  'IRAN' 'BOSNIA & HERZEGOVINA' 'GHANA' 'SRI LANKA' 'ECUADOR' 'MOLDOVA'
#  'NIGERIA' 'CYPRUS' 'TUNISIA' 'SAUDI ARABIA' 'KUWAIT' 'QATAR'
#  'UNITED ARAB EMIRATES' 'OMAN' 'LEBANON' 'BAHRAIN' 'MYANMAR' 'AZERBAIJAN'
#  'ARMENIA' 'PARAGUAY' 'PALESTINE' 'CAMEROON' 'KENYA' 'ETHIOPIA' 'SENEGAL'
#  'KYRGYZSTAN' 'MONTENEGRO' 'ALBANIA' 'UZBEKISTAN' 'BANGLADESH'
#  'KAZAKHSTAN' 'ZAMBIA' 'MADAGASCAR' 'MAURITIUS' 'GEORGIA' 'ALGERIA'
#  'VENEZUELA' 'EL SALVADOR' 'IRAQ' 'JAMAICA' 'NEPAL' 'IRELAND'
#  'NORTHERN IRELAND' 'PANAMA' 'REMOTE' 'CZECH REPUBLIC']
# Total unique countries: 118
